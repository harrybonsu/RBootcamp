# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
# Build a base URL to query Weather Map Websitequery URL
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url =  url + "appid=" + weather_api_key + "&units=imperial"

# %%
# Create lists to append API data
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# call counter
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the cities list 
for city in cities:  
    
    # Try statement to append calls where value is found 
        try: 
        response = requests.get(f"{query_url}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Brigantine
# http://api.openweathermap.org/data/2.5/weather?&q=brigantine
# Processing Record 2 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# City not found. Skipping...
# Processing Record 3 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 4 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# Processing Record 5 | Isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 6 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?&q=port augusta
# Processing Record 7 | Albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 8 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# City not found. Skipping...
# Processing Record 9 | Nanyamba
# http://api.openweathermap.org/data/2.5/weather?&q=nanyamba
# Processing Record 10 | Herat Province
# http://api.openweathermap.org/data/2.5/weather?&q=herat
# Processing Record 11 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 12 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 13 | Iberia
# http://api.openweathermap.org/data/2.5/weather?&q=iberia
# Processing Record 14 | Cherlak
# http://api.openweathermap.org/data/2.5/weather?&q=cherlak
# Processing Record 15 | Airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 16 | Zahirābād
# http://api.openweathermap.org/data/2.5/weather?&q=zahirabad
# Processing Record 17 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 18 | Tigil'
# http://api.openweathermap.org/data/2.5/weather?&q=tigil
# Processing Record 19 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?&q=talcahuano
# Processing Record 20 | Hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 21 | Coyhaique
# http://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 22 | Karratha
# http://api.openweathermap.org/data/2.5/weather?&q=karratha
# Processing Record 23 | Río Gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 24 | Azare
# http://api.openweathermap.org/data/2.5/weather?&q=azare
# Processing Record 25 | Japura
# http://api.openweathermap.org/data/2.5/weather?&q=japura
# Processing Record 26 | Alpena
# http://api.openweathermap.org/data/2.5/weather?&q=alpena
# Processing Record 27 | Kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# City not found. Skipping...
# Processing Record 28 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?&q=tessalit
# Processing Record 29 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 30 | Vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 31 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?&q=bilibino
# Processing Record 32 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 33 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 34 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 36 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 37 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?&q=antalaha
# Processing Record 38 | Busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 39 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 40 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 41 | Bilma
# http://api.openweathermap.org/data/2.5/weather?&q=bilma
# Processing Record 42 | Tautira
# http://api.openweathermap.org/data/2.5/weather?&q=tautira
# Processing Record 43 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 44 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 45 | Port Shepstone
# http://api.openweathermap.org/data/2.5/weather?&q=port shepstone
# Processing Record 46 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 47 | Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 48 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?&q=alyangula
# Processing Record 49 | Atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 50 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?&q=bambanglipuro
# Processing Record 51 | Khovd
# http://api.openweathermap.org/data/2.5/weather?&q=hovd
# Processing Record 52 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 53 | San José Ojetenán
# http://api.openweathermap.org/data/2.5/weather?&q=san jose ojetenan
# Processing Record 54 | Kindu
# http://api.openweathermap.org/data/2.5/weather?&q=kindu
# Processing Record 55 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?&q=dunedin
# Processing Record 56 | Rincon
# http://api.openweathermap.org/data/2.5/weather?&q=rincon
# Processing Record 57 | Rundu
# http://api.openweathermap.org/data/2.5/weather?&q=rundu
# City not found. Skipping...
# Processing Record 58 | Lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 59 | George Town
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 60 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 61 | Bartlesville
# http://api.openweathermap.org/data/2.5/weather?&q=bartlesville
# Processing Record 62 | Lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 63 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# City not found. Skipping...
# Processing Record 64 | Ust'-Kut
# http://api.openweathermap.org/data/2.5/weather?&q=ust-kut
# Processing Record 65 | Hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 66 | Solwezi
# http://api.openweathermap.org/data/2.5/weather?&q=solwezi
# Processing Record 67 | Khani
# http://api.openweathermap.org/data/2.5/weather?&q=khani
# Processing Record 68 | Castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# City not found. Skipping...
# Processing Record 69 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 70 | Hīt
# http://api.openweathermap.org/data/2.5/weather?&q=hit
# Processing Record 71 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 72 | Sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 73 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 74 | Saint-François
# http://api.openweathermap.org/data/2.5/weather?&q=saint-francois
# Processing Record 75 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 76 | Barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 77 | Manggar
# http://api.openweathermap.org/data/2.5/weather?&q=manggar
# Processing Record 78 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 79 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# Processing Record 80 | Samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 81 | East London
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 82 | Homer
# http://api.openweathermap.org/data/2.5/weather?&q=homer
# Processing Record 83 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 84 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 85 | Mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 86 | Dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 87 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 88 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 89 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 90 | Lichinga
# http://api.openweathermap.org/data/2.5/weather?&q=lichinga
# Processing Record 91 | Erdenet
# http://api.openweathermap.org/data/2.5/weather?&q=erdenet
# Processing Record 92 | Chaman
# http://api.openweathermap.org/data/2.5/weather?&q=chaman
# Processing Record 93 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 94 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 95 | Tambacounda
# http://api.openweathermap.org/data/2.5/weather?&q=tambacounda
# Processing Record 96 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 97 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 98 | Salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 99 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# Processing Record 100 | Dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?&q=dhidhdhoo
# Processing Record 101 | Kapit
# http://api.openweathermap.org/data/2.5/weather?&q=kapit
# Processing Record 102 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 103 | Vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 104 | Pemangkat
# http://api.openweathermap.org/data/2.5/weather?&q=pemangkat
# Processing Record 105 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 106 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 107 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 108 | Abu Samrah
# http://api.openweathermap.org/data/2.5/weather?&q=abu samrah
# Processing Record 109 | Sabang
# http://api.openweathermap.org/data/2.5/weather?&q=sabang
# Processing Record 110 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?&q=richards bay
# Processing Record 111 | Hanna
# http://api.openweathermap.org/data/2.5/weather?&q=hanna
# Processing Record 112 | Maniwaki
# http://api.openweathermap.org/data/2.5/weather?&q=maniwaki
# Processing Record 113 | Avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 114 | Poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# City not found. Skipping...
# Processing Record 115 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 116 | Punta Alta
# http://api.openweathermap.org/data/2.5/weather?&q=punta alta
# Processing Record 117 | Tadine
# http://api.openweathermap.org/data/2.5/weather?&q=tadine
# Processing Record 118 | Itaituba
# http://api.openweathermap.org/data/2.5/weather?&q=itaituba
# Processing Record 119 | Sharjah city
# http://api.openweathermap.org/data/2.5/weather?&q=sharjah
# City not found. Skipping...
# Processing Record 120 | Thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 121 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 122 | Bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 123 | Geelong
# http://api.openweathermap.org/data/2.5/weather?&q=geelong
# Processing Record 124 | Oktyabr'skoye
# http://api.openweathermap.org/data/2.5/weather?&q=oktyabrskoye
# Processing Record 125 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 126 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?&q=elizabeth city
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 127 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 128 | Pinos
# http://api.openweathermap.org/data/2.5/weather?&q=pinos
# Processing Record 129 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?&q=oussouye
# Processing Record 130 | Shache
# http://api.openweathermap.org/data/2.5/weather?&q=shache
# Processing Record 131 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?&q=ketchikan
# Processing Record 132 | Saint George
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 133 | Korla
# http://api.openweathermap.org/data/2.5/weather?&q=korla
# Processing Record 134 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# Processing Record 135 | Pahlgām
# http://api.openweathermap.org/data/2.5/weather?&q=pahalgam
# Processing Record 136 | Provincia di Imperia
# http://api.openweathermap.org/data/2.5/weather?&q=imperia
# Processing Record 137 | North Bend
# http://api.openweathermap.org/data/2.5/weather?&q=north bend
# Processing Record 138 | Kaliua
# http://api.openweathermap.org/data/2.5/weather?&q=kaliua
# Processing Record 139 | Sola
# http://api.openweathermap.org/data/2.5/weather?&q=sola
# Processing Record 140 | Sept-Îles
# http://api.openweathermap.org/data/2.5/weather?&q=sept-iles
# Processing Record 141 | Cochrane
# http://api.openweathermap.org/data/2.5/weather?&q=cochrane
# Processing Record 142 | Seoul
# http://api.openweathermap.org/data/2.5/weather?&q=seoul
# City not found. Skipping...
# Processing Record 143 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 144 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 145 | Kiryat Gat
# http://api.openweathermap.org/data/2.5/weather?&q=gat
# Processing Record 146 | Esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 147 | Namanga
# http://api.openweathermap.org/data/2.5/weather?&q=namanga
# Processing Record 148 | Shingū
# http://api.openweathermap.org/data/2.5/weather?&q=shingu
# Processing Record 149 | Platteville
# http://api.openweathermap.org/data/2.5/weather?&q=platteville
# Processing Record 150 | Dhār
# http://api.openweathermap.org/data/2.5/weather?&q=dhar
# Processing Record 151 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# Processing Record 152 | Kumul
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# City not found. Skipping...
# Processing Record 153 | Zharkovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=zharkovskiy
# Processing Record 154 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 155 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 156 | Vardø
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# Processing Record 157 | Novyye Burasy
# http://api.openweathermap.org/data/2.5/weather?&q=novyye burasy
# Processing Record 158 | Novy Urengoy
# http://api.openweathermap.org/data/2.5/weather?&q=novyy urengoy
# City not found. Skipping...
# Processing Record 159 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# City not found. Skipping...
# Processing Record 160 | Bahía Blanca
# http://api.openweathermap.org/data/2.5/weather?&q=bahia blanca
# Processing Record 161 | Chui
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 162 | Samāstipur
# http://api.openweathermap.org/data/2.5/weather?&q=samastipur
# City not found. Skipping...
# Processing Record 163 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 164 | Zlobin
# http://api.openweathermap.org/data/2.5/weather?&q=zlobin
# Processing Record 165 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?&q=mandalgovi
# Processing Record 166 | Palmer
# http://api.openweathermap.org/data/2.5/weather?&q=palmer
# Processing Record 167 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# City not found. Skipping...
# Processing Record 168 | Laas
# http://api.openweathermap.org/data/2.5/weather?&q=lasa
# Processing Record 169 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 170 | Kendari
# http://api.openweathermap.org/data/2.5/weather?&q=kendari
# Processing Record 171 | Banjar
# http://api.openweathermap.org/data/2.5/weather?&q=banjar
# Processing Record 172 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 173 | Broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 174 | Pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 175 | Lethem
# http://api.openweathermap.org/data/2.5/weather?&q=lethem
# Processing Record 176 | Esim
# http://api.openweathermap.org/data/2.5/weather?&q=axim
# Processing Record 177 | Teruel
# http://api.openweathermap.org/data/2.5/weather?&q=teruel
# Processing Record 178 | Zhuhai
# http://api.openweathermap.org/data/2.5/weather?&q=zhuhai
# Processing Record 179 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 180 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 181 | Dauphin
# http://api.openweathermap.org/data/2.5/weather?&q=dauphin
# City not found. Skipping...
# Processing Record 182 | Whitianga
# http://api.openweathermap.org/data/2.5/weather?&q=whitianga
# City not found. Skipping...
# Processing Record 183 | Emerald
# http://api.openweathermap.org/data/2.5/weather?&q=emerald
# City not found. Skipping...
# Processing Record 184 | Raigarh
# http://api.openweathermap.org/data/2.5/weather?&q=raigarh
# Processing Record 185 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnevilyuysk
# Processing Record 186 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=kudahuvadhoo
# Processing Record 187 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 188 | Nago
# http://api.openweathermap.org/data/2.5/weather?&q=nago
# City not found. Skipping...
# Processing Record 189 | Tamiahua
# http://api.openweathermap.org/data/2.5/weather?&q=tamiahua
# Processing Record 190 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?&q=port hedland
# Processing Record 191 | Zinder
# http://api.openweathermap.org/data/2.5/weather?&q=zinder
# City not found. Skipping...
# Processing Record 192 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# City not found. Skipping...
# Processing Record 193 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 194 | Torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 195 | Coruripe
# http://api.openweathermap.org/data/2.5/weather?&q=coruripe
# Processing Record 196 | Pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 197 | Kilkenny
# http://api.openweathermap.org/data/2.5/weather?&q=kilkenny
# Processing Record 198 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 199 | Kargasok
# http://api.openweathermap.org/data/2.5/weather?&q=kargasok
# Processing Record 200 | Sakakah
# http://api.openweathermap.org/data/2.5/weather?&q=sakakah
# Processing Record 201 | Dabola
# http://api.openweathermap.org/data/2.5/weather?&q=dabola
# Processing Record 202 | Kolpashevo
# http://api.openweathermap.org/data/2.5/weather?&q=kolpashevo
# Processing Record 203 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?&q=atbasar
# Processing Record 204 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 205 | Stornoway
# http://api.openweathermap.org/data/2.5/weather?&q=stornoway
# Processing Record 206 | Bayburt
# http://api.openweathermap.org/data/2.5/weather?&q=bayburt
# Processing Record 207 | Vila
# http://api.openweathermap.org/data/2.5/weather?&q=vila
# Processing Record 208 | Taylorville
# http://api.openweathermap.org/data/2.5/weather?&q=taylorville
# Processing Record 209 | Nakhon Thai
# http://api.openweathermap.org/data/2.5/weather?&q=nakhon thai
# Processing Record 210 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?&q=hobyo
# Processing Record 211 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 212 | Alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 213 | Tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 214 | Havre-St-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# Processing Record 215 | Ternate
# http://api.openweathermap.org/data/2.5/weather?&q=ternate
# Processing Record 216 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 217 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 218 | San Miguel de Tucumán
# http://api.openweathermap.org/data/2.5/weather?&q=tucuman
# Processing Record 219 | Westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# Processing Record 220 | Murygino
# http://api.openweathermap.org/data/2.5/weather?&q=murygino
# Processing Record 221 | Arrondissement de Saint-Denis
# http://api.openweathermap.org/data/2.5/weather?&q=saint-denis
# Processing Record 222 | Clearlake
# http://api.openweathermap.org/data/2.5/weather?&q=clearlake
# Processing Record 223 | Vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# Processing Record 224 | Catherinas Lust
# http://api.openweathermap.org/data/2.5/weather?&q=fort wellington
# Processing Record 225 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# City not found. Skipping...
# Processing Record 226 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 227 | Bor
# http://api.openweathermap.org/data/2.5/weather?&q=bor
# Processing Record 228 | Porkhov
# http://api.openweathermap.org/data/2.5/weather?&q=porkhov
# City not found. Skipping...
# Processing Record 229 | Chirongui
# http://api.openweathermap.org/data/2.5/weather?&q=chirongui
# Processing Record 230 | Arrondissement de Rennes
# http://api.openweathermap.org/data/2.5/weather?&q=rennes
# Processing Record 231 | Al Bardīyah
# http://api.openweathermap.org/data/2.5/weather?&q=bardiyah
# Processing Record 232 | Honningsvåg
# http://api.openweathermap.org/data/2.5/weather?&q=honningsvag
# Processing Record 233 | Penhold
# http://api.openweathermap.org/data/2.5/weather?&q=penhold
# Processing Record 234 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?&q=porbandar
# Processing Record 235 | Otavi
# http://api.openweathermap.org/data/2.5/weather?&q=otavi
# Processing Record 236 | Manicoré
# http://api.openweathermap.org/data/2.5/weather?&q=manicore
# Processing Record 237 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 238 | Manali
# http://api.openweathermap.org/data/2.5/weather?&q=manali
# Processing Record 239 | Pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?&q=pangkalanbuun
# Processing Record 240 | Sayyan
# http://api.openweathermap.org/data/2.5/weather?&q=sayyan
# Processing Record 241 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 242 | Matara
# http://api.openweathermap.org/data/2.5/weather?&q=matara
# Processing Record 243 | Birin
# http://api.openweathermap.org/data/2.5/weather?&q=birin
# Processing Record 244 | Puerto Quijarro
# http://api.openweathermap.org/data/2.5/weather?&q=puerto quijarro
# City not found. Skipping...
# Processing Record 245 | Lowestoft
# http://api.openweathermap.org/data/2.5/weather?&q=lowestoft
# City not found. Skipping...
# Processing Record 246 | Shubarshi
# http://api.openweathermap.org/data/2.5/weather?&q=shubarshi
# Processing Record 247 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 248 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?&q=grand gaube
# Processing Record 249 | Trat
# http://api.openweathermap.org/data/2.5/weather?&q=trat
# Processing Record 250 | Bukama
# http://api.openweathermap.org/data/2.5/weather?&q=bukama
# Processing Record 251 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 252 | Mikuni
# http://api.openweathermap.org/data/2.5/weather?&q=mikuni
# Processing Record 253 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 254 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?&q=banda aceh
# Processing Record 255 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# Processing Record 256 | Álamo
# http://api.openweathermap.org/data/2.5/weather?&q=alamo
# Processing Record 257 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 258 | Chengde
# http://api.openweathermap.org/data/2.5/weather?&q=chengde
# Processing Record 259 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 260 | Dukat
# http://api.openweathermap.org/data/2.5/weather?&q=dukat
# Processing Record 261 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?&q=bengkulu
# Processing Record 262 | Burnie
# http://api.openweathermap.org/data/2.5/weather?&q=burnie
# Processing Record 263 | Goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 264 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?&q=ust-nera
# Processing Record 265 | Katherine
# http://api.openweathermap.org/data/2.5/weather?&q=katherine
# Processing Record 266 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 267 | College
# http://api.openweathermap.org/data/2.5/weather?&q=college
# Processing Record 268 | Itoman
# http://api.openweathermap.org/data/2.5/weather?&q=itoman
# Processing Record 269 | Tāndā
# http://api.openweathermap.org/data/2.5/weather?&q=tanda
# Processing Record 270 | Biltine
# http://api.openweathermap.org/data/2.5/weather?&q=biltine
# Processing Record 271 | Kyzyl-Oktyabr
# http://api.openweathermap.org/data/2.5/weather?&q=kyzyl-oktyabr
# Processing Record 272 | Fes
# http://api.openweathermap.org/data/2.5/weather?&q=fez
# Processing Record 273 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?&q=belyy yar
# Processing Record 274 | Camabatela
# http://api.openweathermap.org/data/2.5/weather?&q=camabatela
# Processing Record 275 | Souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 276 | Kaa-Khem
# http://api.openweathermap.org/data/2.5/weather?&q=kaa-khem
# Processing Record 277 | Omboué
# http://api.openweathermap.org/data/2.5/weather?&q=omboue
# Processing Record 278 | Yulara
# http://api.openweathermap.org/data/2.5/weather?&q=yulara
# Processing Record 279 | Carballo
# http://api.openweathermap.org/data/2.5/weather?&q=carballo
# Processing Record 280 | Tommot
# http://api.openweathermap.org/data/2.5/weather?&q=tommot
# Processing Record 281 | Kuytun
# http://api.openweathermap.org/data/2.5/weather?&q=kuytun
# City not found. Skipping...
# Processing Record 282 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 283 | Davila
# http://api.openweathermap.org/data/2.5/weather?&q=davila
# Processing Record 284 | Polonnaruwa
# http://api.openweathermap.org/data/2.5/weather?&q=polonnaruwa
# Processing Record 285 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 286 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 287 | Araure
# http://api.openweathermap.org/data/2.5/weather?&q=araure
# Processing Record 288 | Birjand
# http://api.openweathermap.org/data/2.5/weather?&q=birjand
# City not found. Skipping...
# Processing Record 289 | Babu
# http://api.openweathermap.org/data/2.5/weather?&q=babu
# Processing Record 290 | Vega de Alatorre
# http://api.openweathermap.org/data/2.5/weather?&q=vega de alatorre
# Processing Record 291 | Maceió
# http://api.openweathermap.org/data/2.5/weather?&q=maceio
# Processing Record 292 | Laguna de Perlas
# http://api.openweathermap.org/data/2.5/weather?&q=laguna de perlas
# Processing Record 293 | Beira
# http://api.openweathermap.org/data/2.5/weather?&q=beira
# City not found. Skipping...
# Processing Record 294 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# Processing Record 295 | Avera
# http://api.openweathermap.org/data/2.5/weather?&q=avera
# Processing Record 296 | Singaraja
# http://api.openweathermap.org/data/2.5/weather?&q=singaraja
# Processing Record 297 | Finschhafen
# http://api.openweathermap.org/data/2.5/weather?&q=finschhafen
# Processing Record 298 | Turinskaya Sloboda
# http://api.openweathermap.org/data/2.5/weather?&q=turinskaya sloboda
# Processing Record 299 | Necochea
# http://api.openweathermap.org/data/2.5/weather?&q=necochea
# Processing Record 300 | Ambovombe
# http://api.openweathermap.org/data/2.5/weather?&q=ambovombe
# Processing Record 301 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?&q=cabedelo
# Processing Record 302 | Portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 303 | Beaver Falls
# http://api.openweathermap.org/data/2.5/weather?&q=beaver falls
# Processing Record 304 | Pueblo
# http://api.openweathermap.org/data/2.5/weather?&q=pueblo
# Processing Record 305 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 306 | Nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# City not found. Skipping...
# Processing Record 307 | Shitanjing
# http://api.openweathermap.org/data/2.5/weather?&q=shitanjing
# Processing Record 308 | Kilindoni
# http://api.openweathermap.org/data/2.5/weather?&q=kilindoni
# Processing Record 309 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?&q=port hawkesbury
# Processing Record 310 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 311 | Nikel
# http://api.openweathermap.org/data/2.5/weather?&q=nikel
# Processing Record 312 | Mapimí
# http://api.openweathermap.org/data/2.5/weather?&q=mapimi
# Processing Record 313 | Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?&q=tres arroyos
# Processing Record 314 | The Valley
# http://api.openweathermap.org/data/2.5/weather?&q=the valley
# Processing Record 315 | Esna
# http://api.openweathermap.org/data/2.5/weather?&q=esna
# Processing Record 316 | Turaif
# http://api.openweathermap.org/data/2.5/weather?&q=turayf
# Processing Record 317 | Nuoro
# http://api.openweathermap.org/data/2.5/weather?&q=nuoro
# Processing Record 318 | Hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# Processing Record 319 | Umba
# http://api.openweathermap.org/data/2.5/weather?&q=umba
# Processing Record 320 | Dwārka
# http://api.openweathermap.org/data/2.5/weather?&q=dwarka
# Processing Record 321 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?&q=marzuq
# Processing Record 322 | Shanting
# http://api.openweathermap.org/data/2.5/weather?&q=shanting
# Processing Record 323 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?&q=maniitsoq
# Processing Record 324 | Liberal
# http://api.openweathermap.org/data/2.5/weather?&q=liberal
# Processing Record 325 | Piaçabuçu
# http://api.openweathermap.org/data/2.5/weather?&q=piacabucu
# Processing Record 326 | Bismarck
# http://api.openweathermap.org/data/2.5/weather?&q=bismarck
# Processing Record 327 | Taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 328 | Praia da Vitória
# http://api.openweathermap.org/data/2.5/weather?&q=praia da vitoria
# Processing Record 329 | Timrå
# http://api.openweathermap.org/data/2.5/weather?&q=timra
# Processing Record 330 | Flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 331 | Ferrandina
# http://api.openweathermap.org/data/2.5/weather?&q=ferrandina
# City not found. Skipping...
# Processing Record 332 | The Pas
# http://api.openweathermap.org/data/2.5/weather?&q=the pas
# Processing Record 333 | Bauchi
# http://api.openweathermap.org/data/2.5/weather?&q=bauchi
# City not found. Skipping...
# Processing Record 334 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 335 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?&q=nishihara
# Processing Record 336 | Phuket
# http://api.openweathermap.org/data/2.5/weather?&q=phuket
# Processing Record 337 | Bose
# http://api.openweathermap.org/data/2.5/weather?&q=bose
# Processing Record 338 | Atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 339 | Upata
# http://api.openweathermap.org/data/2.5/weather?&q=upata
# Processing Record 340 | Berbera
# http://api.openweathermap.org/data/2.5/weather?&q=berbera
# Processing Record 341 | Constitución
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 342 | Sørland
# http://api.openweathermap.org/data/2.5/weather?&q=sorland
# Processing Record 343 | Bima
# http://api.openweathermap.org/data/2.5/weather?&q=bima
# Processing Record 344 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?&q=kangaatsiaq
# Processing Record 345 | Roswell
# http://api.openweathermap.org/data/2.5/weather?&q=roswell
# Processing Record 346 | Djibo
# http://api.openweathermap.org/data/2.5/weather?&q=djibo
# Processing Record 347 | Weiswampach
# http://api.openweathermap.org/data/2.5/weather?&q=weiswampach
# Processing Record 348 | Manta
# http://api.openweathermap.org/data/2.5/weather?&q=manta
# Processing Record 349 | Kidal
# http://api.openweathermap.org/data/2.5/weather?&q=kidal
# Processing Record 350 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?&q=grindavik
# Processing Record 351 | Domoni
# http://api.openweathermap.org/data/2.5/weather?&q=domoni
# Processing Record 352 | El Viejo
# http://api.openweathermap.org/data/2.5/weather?&q=el viejo
# Processing Record 353 | Krasnosel'kup
# http://api.openweathermap.org/data/2.5/weather?&q=krasnoselkup
# Processing Record 354 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 355 | Yerbogachën
# http://api.openweathermap.org/data/2.5/weather?&q=yerbogachen
# Processing Record 356 | Moses Lake
# http://api.openweathermap.org/data/2.5/weather?&q=moses lake
# Processing Record 357 | Dingcheng
# http://api.openweathermap.org/data/2.5/weather?&q=huangchuan
# Processing Record 358 | Fallon
# http://api.openweathermap.org/data/2.5/weather?&q=fallon
# Processing Record 359 | Mariehamn
# http://api.openweathermap.org/data/2.5/weather?&q=maarianhamina
# Processing Record 360 | Sorong
# http://api.openweathermap.org/data/2.5/weather?&q=sorong
# Processing Record 361 | Balaipungut
# http://api.openweathermap.org/data/2.5/weather?&q=balaipungut
# Processing Record 362 | Clacton-on-Sea
# http://api.openweathermap.org/data/2.5/weather?&q=clacton-on-sea
# Processing Record 363 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 364 | Būlaevo
# http://api.openweathermap.org/data/2.5/weather?&q=bulaevo
# Processing Record 365 | Matamoros
# http://api.openweathermap.org/data/2.5/weather?&q=matamoros
# Processing Record 366 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?&q=carutapera
# Processing Record 367 | Marabu
# http://api.openweathermap.org/data/2.5/weather?&q=miri
# Processing Record 368 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 369 | Honiara
# http://api.openweathermap.org/data/2.5/weather?&q=honiara
# Processing Record 370 | Dekar
# http://api.openweathermap.org/data/2.5/weather?&q=dekar
# Processing Record 371 | Yelabuga
# http://api.openweathermap.org/data/2.5/weather?&q=yelabuga
# Processing Record 372 | Porto-Novo
# http://api.openweathermap.org/data/2.5/weather?&q=porto novo
# Processing Record 373 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?&q=manokwari
# Processing Record 374 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 375 | Barentu
# http://api.openweathermap.org/data/2.5/weather?&q=barentu
# Processing Record 376 | Koutsouras
# http://api.openweathermap.org/data/2.5/weather?&q=koutsouras
# Processing Record 377 | Kefamenanu
# http://api.openweathermap.org/data/2.5/weather?&q=kefamenanu
# Processing Record 378 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?&q=kysyl-syr
# Processing Record 379 | La Palma
# http://api.openweathermap.org/data/2.5/weather?&q=la palma
# Processing Record 380 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?&q=taoudenni
# Processing Record 381 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 382 | Härnösand
# http://api.openweathermap.org/data/2.5/weather?&q=harnosand
# Processing Record 383 | Shatura
# http://api.openweathermap.org/data/2.5/weather?&q=shatura
# Processing Record 384 | Snyder
# http://api.openweathermap.org/data/2.5/weather?&q=snyder
# Processing Record 385 | Texarkana
# http://api.openweathermap.org/data/2.5/weather?&q=texarkana
# City not found. Skipping...
# Processing Record 386 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?&q=hambantota
# City not found. Skipping...
# Processing Record 387 | Codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 388 | San Quintín
# http://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 389 | Mileb
# http://api.openweathermap.org/data/2.5/weather?&q=mileb
# Processing Record 390 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?&q=mayumba
# Processing Record 391 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 392 | Aras
# http://api.openweathermap.org/data/2.5/weather?&q=aras
# Processing Record 393 | Podporozh'ye
# http://api.openweathermap.org/data/2.5/weather?&q=podporozhye
# Processing Record 394 | Neuquén
# http://api.openweathermap.org/data/2.5/weather?&q=neuquen
# Processing Record 395 | Margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 396 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?&q=nantucket
# Processing Record 397 | Filingué
# http://api.openweathermap.org/data/2.5/weather?&q=filingue
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 398 | Laguna
# http://api.openweathermap.org/data/2.5/weather?&q=laguna
# Processing Record 399 | Darhan
# http://api.openweathermap.org/data/2.5/weather?&q=darhan
# Processing Record 400 | ‘Ewa Beach
# http://api.openweathermap.org/data/2.5/weather?&q=ewa beach
# Processing Record 401 | Bratsk
# http://api.openweathermap.org/data/2.5/weather?&q=bratsk
# Processing Record 402 | Beloha
# http://api.openweathermap.org/data/2.5/weather?&q=beloha
# Processing Record 403 | Mazamet
# http://api.openweathermap.org/data/2.5/weather?&q=mazamet
# Processing Record 404 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 405 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# Processing Record 406 | Ampanihy
# http://api.openweathermap.org/data/2.5/weather?&q=ampanihy
# Processing Record 407 | Fort Frances
# http://api.openweathermap.org/data/2.5/weather?&q=fort frances
# Processing Record 408 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 409 | Faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 410 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 411 | Chazuta
# http://api.openweathermap.org/data/2.5/weather?&q=chazuta
# Processing Record 412 | Maumere
# http://api.openweathermap.org/data/2.5/weather?&q=maumere
# Processing Record 413 | Kimberley
# http://api.openweathermap.org/data/2.5/weather?&q=kimberley
# Processing Record 414 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?&q=boa vista
# Processing Record 415 | Ekhabi
# http://api.openweathermap.org/data/2.5/weather?&q=ekhabi
# Processing Record 416 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 417 | Ust'-Tarka
# http://api.openweathermap.org/data/2.5/weather?&q=ust-tarka
# Processing Record 418 | Sur
# http://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 419 | Kepanjen
# http://api.openweathermap.org/data/2.5/weather?&q=kepanjen
# Processing Record 420 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# Processing Record 421 | Humaitá
# http://api.openweathermap.org/data/2.5/weather?&q=humaita
# Processing Record 422 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?&q=fort nelson
# Processing Record 423 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 424 | Sajanan
# http://api.openweathermap.org/data/2.5/weather?&q=sajanan
# Processing Record 425 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?&q=byron bay
# Processing Record 426 | João Pinheiro
# http://api.openweathermap.org/data/2.5/weather?&q=joao pinheiro
# Processing Record 427 | Santiago de Cao
# http://api.openweathermap.org/data/2.5/weather?&q=santiago de cao
# Processing Record 428 | Isiro
# http://api.openweathermap.org/data/2.5/weather?&q=isiro
# Processing Record 429 | Najrān
# http://api.openweathermap.org/data/2.5/weather?&q=najran
# Processing Record 430 | Cary
# http://api.openweathermap.org/data/2.5/weather?&q=cary
# Processing Record 431 | Vanino
# http://api.openweathermap.org/data/2.5/weather?&q=vanino
# Processing Record 432 | Jamiltepec
# http://api.openweathermap.org/data/2.5/weather?&q=jamiltepec
# Processing Record 433 | Mackay
# http://api.openweathermap.org/data/2.5/weather?&q=mackay
# Processing Record 434 | Stavern
# http://api.openweathermap.org/data/2.5/weather?&q=stavern
# Processing Record 435 | Todos Santos
# http://api.openweathermap.org/data/2.5/weather?&q=todos santos
# Processing Record 436 | Carbonia
# http://api.openweathermap.org/data/2.5/weather?&q=carbonia
# Processing Record 437 | Kampot
# http://api.openweathermap.org/data/2.5/weather?&q=kampot
# Processing Record 438 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?&q=boyolangu
# Processing Record 439 | Dubna
# http://api.openweathermap.org/data/2.5/weather?&q=dubna
# Processing Record 440 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?&q=kaeo
# Processing Record 441 | Sawtell
# http://api.openweathermap.org/data/2.5/weather?&q=sawtell
# Processing Record 442 | Daru
# http://api.openweathermap.org/data/2.5/weather?&q=daru
# Processing Record 443 | Balabac
# http://api.openweathermap.org/data/2.5/weather?&q=balabac
# City not found. Skipping...
# Processing Record 444 | Kushima
# http://api.openweathermap.org/data/2.5/weather?&q=kushima
# Processing Record 445 | Zaysan
# http://api.openweathermap.org/data/2.5/weather?&q=zaysan
# Processing Record 446 | Chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 447 | Husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# Processing Record 448 | Deputatsky
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 449 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?&q=shenjiamen
# Processing Record 450 | Mbandaka
# http://api.openweathermap.org/data/2.5/weather?&q=mbandaka
# Processing Record 451 | Totness
# http://api.openweathermap.org/data/2.5/weather?&q=totness
# Processing Record 452 | Olinda
# http://api.openweathermap.org/data/2.5/weather?&q=olinda
# Processing Record 453 | Kampong Chhnang
# http://api.openweathermap.org/data/2.5/weather?&q=kampong chhnang
# Processing Record 454 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 455 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?&q=saint-joseph
# Processing Record 456 | Sillamäe
# http://api.openweathermap.org/data/2.5/weather?&q=sillamae
# Processing Record 457 | Ati
# http://api.openweathermap.org/data/2.5/weather?&q=ati
# Processing Record 458 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?&q=anadyr
# Processing Record 459 | Novikovo
# http://api.openweathermap.org/data/2.5/weather?&q=novikovo
# Processing Record 460 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?&q=kirakira
# Processing Record 461 | Svarstad
# http://api.openweathermap.org/data/2.5/weather?&q=svarstad
# Processing Record 462 | Sylacauga
# http://api.openweathermap.org/data/2.5/weather?&q=sylacauga
# Processing Record 463 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 464 | Jurm
# http://api.openweathermap.org/data/2.5/weather?&q=jurm
# Processing Record 465 | Nipawin
# http://api.openweathermap.org/data/2.5/weather?&q=nipawin
# Processing Record 466 | Litovko
# http://api.openweathermap.org/data/2.5/weather?&q=litovko
# Processing Record 467 | Palu
# http://api.openweathermap.org/data/2.5/weather?&q=palu
# Processing Record 468 | Kīhei
# http://api.openweathermap.org/data/2.5/weather?&q=kihei
# Processing Record 469 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 470 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?&q=savannah bight
# Processing Record 471 | Weyburn
# http://api.openweathermap.org/data/2.5/weather?&q=weyburn
# Processing Record 472 | Saint-Médard-en-Jalles
# http://api.openweathermap.org/data/2.5/weather?&q=saint-medard-en-jalles
# Processing Record 473 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?&q=inhambane
# Processing Record 474 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?&q=sobolevo
# Processing Record 475 | Ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 476 | Hay River
# http://api.openweathermap.org/data/2.5/weather?&q=hay river
# Processing Record 477 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?&q=bay roberts
# Processing Record 478 | Asău
# http://api.openweathermap.org/data/2.5/weather?&q=asau
# Processing Record 479 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?&q=kumluca
# Processing Record 480 | Newton
# http://api.openweathermap.org/data/2.5/weather?&q=newton
# Processing Record 481 | Colares
# http://api.openweathermap.org/data/2.5/weather?&q=colares
# Processing Record 482 | Ghanzi
# http://api.openweathermap.org/data/2.5/weather?&q=ghanzi
# Processing Record 483 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# Processing Record 484 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?&q=nemuro
# Processing Record 485 | Isla Vista
# http://api.openweathermap.org/data/2.5/weather?&q=isla vista
# Processing Record 486 | Basco
# http://api.openweathermap.org/data/2.5/weather?&q=basco
# Processing Record 487 | Susanville
# http://api.openweathermap.org/data/2.5/weather?&q=susanville
# Processing Record 488 | Along
# http://api.openweathermap.org/data/2.5/weather?&q=along
# Processing Record 489 | Am Timan
# http://api.openweathermap.org/data/2.5/weather?&q=am timan
# Processing Record 490 | Hashtrūd
# http://api.openweathermap.org/data/2.5/weather?&q=hashtrud
# Processing Record 491 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# Processing Record 492 | Loksa
# http://api.openweathermap.org/data/2.5/weather?&q=loksa
# Processing Record 493 | Kaseda-shirakame
# http://api.openweathermap.org/data/2.5/weather?&q=kaseda
# Processing Record 494 | Tam Ky
# http://api.openweathermap.org/data/2.5/weather?&q=tam ky
# Processing Record 495 | Ballina
# http://api.openweathermap.org/data/2.5/weather?&q=ballina
# Processing Record 496 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?&q=nhulunbuy
# Processing Record 497 | Altamira
# http://api.openweathermap.org/data/2.5/weather?&q=altamira
# Processing Record 498 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?&q=tiarei
# Processing Record 499 | Yangi Marg`ilon
# http://api.openweathermap.org/data/2.5/weather?&q=komsomolskiy
# Processing Record 500 | Mufulira
# http://api.openweathermap.org/data/2.5/weather?&q=mufulira
# City not found. Skipping...
# Processing Record 501 | Oodweyne
# http://api.openweathermap.org/data/2.5/weather?&q=odweyne
# Processing Record 502 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?&q=kungurtug
# Processing Record 503 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 504 | Novovelichkovskaya
# http://api.openweathermap.org/data/2.5/weather?&q=novovelichkovskaya
# Processing Record 505 | Tokur
# http://api.openweathermap.org/data/2.5/weather?&q=tokur
# Processing Record 506 | Kiama
# http://api.openweathermap.org/data/2.5/weather?&q=kiama
# Processing Record 507 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?&q=aasiaat
# Processing Record 508 | Amahai
# http://api.openweathermap.org/data/2.5/weather?&q=amahai
# Processing Record 509 | Coswig
# http://api.openweathermap.org/data/2.5/weather?&q=coswig
# Processing Record 510 | Izvestkovyy
# http://api.openweathermap.org/data/2.5/weather?&q=izvestkovyy
# Processing Record 511 | Djambala
# http://api.openweathermap.org/data/2.5/weather?&q=djambala
# Processing Record 512 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?&q=quatre cocos
# Processing Record 513 | Pedreiras
# http://api.openweathermap.org/data/2.5/weather?&q=pedreiras
# City not found. Skipping...
# Processing Record 514 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?&q=sibolga
# Processing Record 515 | Buala
# http://api.openweathermap.org/data/2.5/weather?&q=buala
# Processing Record 516 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 517 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 518 | Kattivākkam
# http://api.openweathermap.org/data/2.5/weather?&q=kattivakkam
# Processing Record 519 | Lufilufi
# http://api.openweathermap.org/data/2.5/weather?&q=lufilufi
# Processing Record 520 | Nelas
# http://api.openweathermap.org/data/2.5/weather?&q=nelas
# Processing Record 521 | Nara
# http://api.openweathermap.org/data/2.5/weather?&q=nara
# Processing Record 522 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?&q=kiunga
# Processing Record 523 | Teseney
# http://api.openweathermap.org/data/2.5/weather?&q=teseney
# Processing Record 524 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# Processing Record 525 | Padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# Processing Record 526 | Sambulawan
# http://api.openweathermap.org/data/2.5/weather?&q=sambulawan
# Processing Record 527 | Soc Trang
# http://api.openweathermap.org/data/2.5/weather?&q=soc trang
# Processing Record 528 | Mapiripán
# http://api.openweathermap.org/data/2.5/weather?&q=mapiripan
# Processing Record 529 | Touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 530 | Springbok
# http://api.openweathermap.org/data/2.5/weather?&q=springbok
# Processing Record 531 | Safi
# http://api.openweathermap.org/data/2.5/weather?&q=asfi
# Processing Record 532 | Porto Velho
# http://api.openweathermap.org/data/2.5/weather?&q=porto velho
# Processing Record 533 | Lima
# http://api.openweathermap.org/data/2.5/weather?&q=lima
# Processing Record 534 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?&q=abu dhabi
# Processing Record 535 | Rock Springs
# http://api.openweathermap.org/data/2.5/weather?&q=rock springs
# Processing Record 536 | Peleduy
# http://api.openweathermap.org/data/2.5/weather?&q=peleduy
# Processing Record 537 | Evanston
# http://api.openweathermap.org/data/2.5/weather?&q=evanston
# Processing Record 538 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?&q=abu kamal
# Processing Record 539 | Liuhe
# http://api.openweathermap.org/data/2.5/weather?&q=liuhe
# Processing Record 540 | Kenai
# http://api.openweathermap.org/data/2.5/weather?&q=kenai
# Processing Record 541 | Barguzin
# http://api.openweathermap.org/data/2.5/weather?&q=barguzin
# Processing Record 542 | Faya
# http://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 543 | Troy
# http://api.openweathermap.org/data/2.5/weather?&q=troy
# Processing Record 544 | Puerto Peñasco
# http://api.openweathermap.org/data/2.5/weather?&q=puerto penasco
# Processing Record 545 | Kutum
# http://api.openweathermap.org/data/2.5/weather?&q=kutum
# Processing Record 546 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?&q=kisangani
# Processing Record 547 | Tianpeng
# http://api.openweathermap.org/data/2.5/weather?&q=tianpeng
# Processing Record 548 | Pará de Minas
# http://api.openweathermap.org/data/2.5/weather?&q=para de minas
# Processing Record 549 | Tshane
# http://api.openweathermap.org/data/2.5/weather?&q=tshane
# Processing Record 550 | Jacobina
# http://api.openweathermap.org/data/2.5/weather?&q=jacobina
# Processing Record 551 | Bauta
# http://api.openweathermap.org/data/2.5/weather?&q=bauta
# Processing Record 552 | Klyuchi
# http://api.openweathermap.org/data/2.5/weather?&q=klyuchi
# City not found. Skipping...
# Processing Record 553 | Pokosnoye
# http://api.openweathermap.org/data/2.5/weather?&q=pokosnoye
# Processing Record 554 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?&q=mareeba
# Processing Record 555 | Tezu
# http://api.openweathermap.org/data/2.5/weather?&q=tezu
# Processing Record 556 | Krasnoarmeyskoye
# http://api.openweathermap.org/data/2.5/weather?&q=krasnoarmeyskoye
# Processing Record 557 | Aktau
# http://api.openweathermap.org/data/2.5/weather?&q=aktau
# Processing Record 558 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# Processing Record 559 | Salihli
# http://api.openweathermap.org/data/2.5/weather?&q=salihli
# Processing Record 560 | Phonhong
# http://api.openweathermap.org/data/2.5/weather?&q=phonhong
# City not found. Skipping...
# Processing Record 561 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?&q=nuuk
# Processing Record 562 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?&q=imbituba
# Processing Record 563 | Mwadui
# http://api.openweathermap.org/data/2.5/weather?&q=mwadui
# Processing Record 564 | Helong
# http://api.openweathermap.org/data/2.5/weather?&q=helong
# Processing Record 565 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 566 | Viking
# http://api.openweathermap.org/data/2.5/weather?&q=viking
# Processing Record 567 | Huanan
# http://api.openweathermap.org/data/2.5/weather?&q=huanan
# Processing Record 568 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?&q=gorontalo
# Processing Record 569 | Pathein
# http://api.openweathermap.org/data/2.5/weather?&q=pathein
# Processing Record 570 | Adrar
# http://api.openweathermap.org/data/2.5/weather?&q=adrar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 571 | Puerto Baquerizo Moreno
# http://api.openweathermap.org/data/2.5/weather?&q=puerto baquerizo moreno
# Processing Record 572 | Lukovetskiy
# http://api.openweathermap.org/data/2.5/weather?&q=lukovetskiy
# Processing Record 573 | Shrewsbury
# http://api.openweathermap.org/data/2.5/weather?&q=shrewsbury

# %%
# create a dictionary to construct dataframe
weather_py = {"City":city_name,
             "Lat":lat,
             "Lng":lng,
             "Max Temp":max_temp,
             "Humidity":humidity,
             "Cloudiness":cloudiness,
             "Wind Speed":wind_speed,
             "Country":country,
             "date":date
             }

weather_df = pd.DataFrame(weather_py)
weather_df
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                   Brigantine  39.4101  -74.3646    286.15        62
# 1                    Jamestown  42.0970  -79.2353    281.15        87
# 2                   Chokurdakh  70.6333  147.9167    250.57        91
# 3    Petropavlovsk-Kamchatskiy  53.0452  158.6483    272.15        47
# 4                      Isangel -19.5500  169.2667    302.15        65
# ..                         ...      ...       ...       ...       ...
# 568                    Pathein  16.7833   94.7333    311.26        17
# 569                      Adrar  20.5022  -10.0711    288.71        34
# 570    Puerto Baquerizo Moreno  -0.9000  -89.6000    298.73        82
# 571                Lukovetskiy  64.2956   41.9211    260.15        72
# 572                 Shrewsbury  52.7101   -2.7521    277.59        93
#
#      Cloudiness  Wind Speed Country        date
# 0             1        4.12      US  1615522491
# 1            90        5.59      US  1615522657
# 2            39        3.38      RU  1615522792
# 3            69        8.00      RU  1615522793
# 4            40        5.14      VU  1615522794
# ..          ...         ...     ...         ...
# 568           0        3.51      MM  1615523540
# 569           4        5.91      MR  1615523542
# 570          97        1.78      EC  1615523543
# 571          40        3.00      RU  1615523544
# 572          75        6.17      GB  1615523546
#
# [573 rows x 9 columns]

# %%
# Export the city data into a CSV
weather_df.to_csv('../output_data/city_data.csv')

# %%
weather_df[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'date']].describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  573.000000
# mean    20.541500   19.417205  285.709546   71.095986   50.762653    3.661169
# std     32.871589   91.429002   15.692060   20.537435   39.424969    2.519108
# min    -54.800000 -175.200000  241.540000    1.000000    0.000000    0.040000
# 25%     -6.981100  -62.272400  275.370000   61.000000    4.000000    1.840000
# 50%     24.416700   25.946900  289.830000   75.000000   53.000000    3.090000
# 75%     48.587200  101.614200  298.310000   86.000000   90.000000    5.100000
# max     78.218600  178.416700  311.260000  100.000000  100.000000   14.920000
#
#                date
# count  5.730000e+02
# mean   1.615523e+09
# std    2.474479e+02
# min    1.615522e+09
# 25%    1.615523e+09
# 50%    1.615523e+09
# 75%    1.615523e+09
# max    1.615524e+09

# %%
#weather_df = weather_df.loc[weather_df['Humidity'] >100 ]
#weather_df.count()

# %% [markdown]
# # Plotting the Data

# %% [markdown]
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.\
# Save the plotted figures as .pngs.

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolors = "black")
plt.title("City Latitude vs. Max Temperature (03/11/2021)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolors = "black")
plt.title("City Latitude vs. Humidity (03/11/2021)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], edgecolors = "black")
plt.title("City Latitude vs. Cloudiness (03/11/2021)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], edgecolors = "black")
plt.title("City Latitude vs. Wind Speed (03/11/2021)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Linear Regression

# %%
north_hem = weather_df.loc[weather_df['Lat']>=0]
south_hem = weather_df.loc[weather_df['Lat']<0]      
south_hem
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 4                    Isangel -19.5500  169.2667    302.15        65
# 5               Port Augusta -32.5000  137.7667    307.15        24
# 7                New Norfolk -42.7826  147.0587    302.04        50
# 8                   Nanyamba -10.6833   39.8333    297.15        94
# 10                   Ushuaia -54.8000  -68.3000    276.15        87
# ..                       ...      ...       ...       ...       ...
# 557              Port-Gentil  -0.7193    8.7815    300.22        81
# 561                 Imbituba -28.2400  -48.6703    295.15        88
# 562                   Mwadui  -3.5500   33.6000    291.30        68
# 564                Namatanai  -3.6667  152.4333    301.62        69
# 570  Puerto Baquerizo Moreno  -0.9000  -89.6000    298.73        82
#
#      Cloudiness  Wind Speed Country        date
# 4            40        5.14      VU  1615522794
# 5             0        4.63      AU  1615522555
# 7            75        3.60      AU  1615522740
# 8            20        3.60      TZ  1615522799
# 10           40        5.14      AR  1615522724
# ..          ...         ...     ...         ...
# 557         100        2.38      GA  1615523525
# 561           0        1.54      BR  1615523531
# 562           0        2.50      TZ  1615523532
# 564         100        2.02      PG  1615523535
# 570          97        1.78      EC  1615523543
#
# [179 rows x 9 columns]

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Max Temp'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(north_hem['Lat'],north_hem['Max Temp'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.annotate(val, (5,245), fontsize=14, color='red')
plt.show()

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(south_hem['Lat'],south_hem['Max Temp'])
fit = s * south_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(south_hem['Lat'],south_hem['Max Temp'])
plt.plot(south_hem['Lat'], fit, "--", color='red')
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.annotate(val, (-30,280), fontsize=14, color='red')
plt.show()

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Humidity'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(north_hem['Lat'],north_hem['Humidity'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Humidity ')
plt.xlabel('Latitude')
plt.annotate(val, (50,18), fontsize=12, color='red')
plt.show()

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(south_hem['Lat'],south_hem['Humidity'])
fit = s * south_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(south_hem['Lat'],south_hem['Humidity'])
plt.plot(south_hem['Lat'], fit, "--", color='red')
plt.ylabel('Humidity ')
plt.xlabel('Latitude')
plt.annotate(val, (-20,30), fontsize=12, color='red')
plt.show()

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Cloudiness'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(north_hem['Lat'],north_hem['Cloudiness'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Cloudiness ')
plt.xlabel('Latitude')
plt.annotate(val, (45,10), fontsize=14, color='red')
plt.show()
