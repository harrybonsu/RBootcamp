# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %%
# Build a base URL to query Weather Map Websitequery URL
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url =  url + "appid=" + weather_api_key + "&units=imperial"

# %%
# Create lists to append API data
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# call counter
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the cities list 
for city in cities:  
    
    # Try statement to append calls where value is found 
        try: 
            response = requests.get(f"{query_url}&q={city}").json()
            city_name.append(response["name"])
            cloudiness.append(response["clouds"]["all"])
            country.append(response["sys"]["country"])
            date.append(response["dt"])
            humidity.append(response["main"]["humidity"])
            max_temp.append(response["main"]["temp_max"])
            lat.append(response["coord"]["lat"])
            lng.append(response["coord"]["lon"])
            wind_speed.append(response["wind"]["speed"])
            city_record = response["name"]
            print(f"Processing Record {record} | {city_record}")
            print(f"{url}&q={city}")

            # Increase counter by one 
            record= record + 1

            # Wait a second in loop to not over exceed rate limit of API
            time.sleep(1.01)
        
    # If no record found "skip" to next call
        except:
            print("City not found. Skipping...")
        continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 2 | Pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 3 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# City not found. Skipping...
# Processing Record 4 | Balyqshy
# http://api.openweathermap.org/data/2.5/weather?&q=balykshi
# Processing Record 5 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 6 | Padilla
# http://api.openweathermap.org/data/2.5/weather?&q=padilla
# Processing Record 7 | Shingū
# http://api.openweathermap.org/data/2.5/weather?&q=shingu
# Processing Record 8 | Mastic Beach
# http://api.openweathermap.org/data/2.5/weather?&q=mastic beach
# Processing Record 9 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 10 | Dravograd
# http://api.openweathermap.org/data/2.5/weather?&q=dravograd
# Processing Record 11 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 12 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 13 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 14 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 15 | Samarkand
# http://api.openweathermap.org/data/2.5/weather?&q=samarkand
# Processing Record 16 | Hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 17 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 18 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 19 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 20 | Araxá
# http://api.openweathermap.org/data/2.5/weather?&q=araxa
# Processing Record 21 | Velsk
# http://api.openweathermap.org/data/2.5/weather?&q=velsk
# Processing Record 22 | Nizhniy Tsasuchey
# http://api.openweathermap.org/data/2.5/weather?&q=nizhniy tsasuchey
# Processing Record 23 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 24 | Si Chiang Mai
# http://api.openweathermap.org/data/2.5/weather?&q=si chiang mai
# Processing Record 25 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 26 | Broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 27 | Biak
# http://api.openweathermap.org/data/2.5/weather?&q=biak
# Processing Record 28 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 29 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 30 | Mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 31 | Denpasar
# http://api.openweathermap.org/data/2.5/weather?&q=denpasar
# Processing Record 32 | Wasilla
# http://api.openweathermap.org/data/2.5/weather?&q=wasilla
# Processing Record 33 | Barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 34 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# City not found. Skipping...
# Processing Record 35 | Calvià
# http://api.openweathermap.org/data/2.5/weather?&q=calvia
# Processing Record 36 | Kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?&q=kulhudhuffushi
# Processing Record 37 | Tromsø
# http://api.openweathermap.org/data/2.5/weather?&q=tromso
# Processing Record 38 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# Processing Record 39 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 40 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 41 | Kiryat Gat
# http://api.openweathermap.org/data/2.5/weather?&q=gat
# Processing Record 42 | Albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 | Vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# Processing Record 45 | Colac
# http://api.openweathermap.org/data/2.5/weather?&q=colac
# Processing Record 46 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 47 | Dodoma
# http://api.openweathermap.org/data/2.5/weather?&q=dodoma
# Processing Record 48 | Bundaberg
# http://api.openweathermap.org/data/2.5/weather?&q=bundaberg
# City not found. Skipping...
# Processing Record 49 | Eenhana
# http://api.openweathermap.org/data/2.5/weather?&q=eenhana
# Processing Record 50 | Luang Prabang
# http://api.openweathermap.org/data/2.5/weather?&q=luang prabang
# Processing Record 51 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 52 | Moindou
# http://api.openweathermap.org/data/2.5/weather?&q=moindou
# Processing Record 53 | Busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 54 | Besao
# http://api.openweathermap.org/data/2.5/weather?&q=besao
# Processing Record 55 | Buraidah
# http://api.openweathermap.org/data/2.5/weather?&q=buraydah
# Processing Record 56 | Brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 57 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 58 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 59 | Longyan
# http://api.openweathermap.org/data/2.5/weather?&q=longyan
# Processing Record 60 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 61 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 62 | Lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 63 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 64 | Tazovsky
# http://api.openweathermap.org/data/2.5/weather?&q=tazovskiy
# Processing Record 65 | Portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 66 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 67 | Beaumont
# http://api.openweathermap.org/data/2.5/weather?&q=beaumont
# Processing Record 68 | Atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 69 | Abatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=abatskoye
# Processing Record 70 | Udachny
# http://api.openweathermap.org/data/2.5/weather?&q=udachnyy
# Processing Record 71 | Vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 72 | Dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 73 | Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 74 | George Town
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 75 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# Processing Record 76 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 77 | Ossora
# http://api.openweathermap.org/data/2.5/weather?&q=ossora
# Processing Record 78 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 79 | Jaguarari
# http://api.openweathermap.org/data/2.5/weather?&q=jaguarari
# Processing Record 80 | Chara
# http://api.openweathermap.org/data/2.5/weather?&q=chara
# Processing Record 81 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# Processing Record 82 | Khanbari
# http://api.openweathermap.org/data/2.5/weather?&q=khandbari
# Processing Record 83 | Yulara
# http://api.openweathermap.org/data/2.5/weather?&q=yulara
# Processing Record 84 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 85 | Tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# Processing Record 86 | Mwinilunga
# http://api.openweathermap.org/data/2.5/weather?&q=mwinilunga
# Processing Record 87 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 88 | Forbes
# http://api.openweathermap.org/data/2.5/weather?&q=forbes
# Processing Record 89 | Villa Unión
# http://api.openweathermap.org/data/2.5/weather?&q=villa union
# Processing Record 90 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# Processing Record 91 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?&q=hervey bay
# City not found. Skipping...
# Processing Record 92 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?&q=ponta delgada
# Processing Record 93 | Naze
# http://api.openweathermap.org/data/2.5/weather?&q=naze
# City not found. Skipping...
# Processing Record 94 | Vila
# http://api.openweathermap.org/data/2.5/weather?&q=vila
# Processing Record 95 | Lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 96 | Lewisporte
# http://api.openweathermap.org/data/2.5/weather?&q=lewisporte
# Processing Record 97 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 98 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?&q=byron bay
# Processing Record 99 | Nkwerre
# http://api.openweathermap.org/data/2.5/weather?&q=nkwerre
# Processing Record 100 | Moussoro
# http://api.openweathermap.org/data/2.5/weather?&q=moussoro
# Processing Record 101 | Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?&q=ciudad bolivar
# Processing Record 102 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?&q=dunedin
# Processing Record 103 | Flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 104 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?&q=boa vista
# Processing Record 105 | Tonstad
# http://api.openweathermap.org/data/2.5/weather?&q=tonstad
# Processing Record 106 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 107 | Cleveland
# http://api.openweathermap.org/data/2.5/weather?&q=cleveland
# Processing Record 108 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 109 | Komsomol'skoye
# http://api.openweathermap.org/data/2.5/weather?&q=komsomolskoye
# Processing Record 110 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# City not found. Skipping...
# Processing Record 111 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 112 | Adrar
# http://api.openweathermap.org/data/2.5/weather?&q=adrar
# Processing Record 113 | Karasjok
# http://api.openweathermap.org/data/2.5/weather?&q=karasjok
# Processing Record 114 | East London
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# City not found. Skipping...
# Processing Record 115 | Praia
# http://api.openweathermap.org/data/2.5/weather?&q=praya
# Processing Record 116 | Hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 117 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 118 | Shirokiy
# http://api.openweathermap.org/data/2.5/weather?&q=shirokiy
# Processing Record 119 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# City not found. Skipping...
# Processing Record 120 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?&q=mareeba
# Processing Record 121 | Los Algarrobos
# http://api.openweathermap.org/data/2.5/weather?&q=los algarrobos
# Processing Record 122 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 123 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?&q=rio grande
# Processing Record 124 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 125 | Lander
# http://api.openweathermap.org/data/2.5/weather?&q=lander
# Processing Record 126 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# City not found. Skipping...
# Processing Record 127 | Reconquista
# http://api.openweathermap.org/data/2.5/weather?&q=reconquista
# Processing Record 128 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?&q=atbasar
# Processing Record 129 | Bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 130 | Tazmalt
# http://api.openweathermap.org/data/2.5/weather?&q=tazmalt
# City not found. Skipping...
# Processing Record 131 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 132 | Poya
# http://api.openweathermap.org/data/2.5/weather?&q=poya
# Processing Record 133 | Touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 134 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?&q=kodinsk
# Processing Record 135 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 136 | Castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 137 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 138 | Chumphon
# http://api.openweathermap.org/data/2.5/weather?&q=chumphon
# Processing Record 139 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 140 | North Bend
# http://api.openweathermap.org/data/2.5/weather?&q=north bend
# Processing Record 141 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?&q=caravelas
# Processing Record 142 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 143 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 144 | São João da Barra
# http://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 145 | Morón
# http://api.openweathermap.org/data/2.5/weather?&q=moron
# Processing Record 146 | Padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# Processing Record 147 | Minoh
# http://api.openweathermap.org/data/2.5/weather?&q=mino
# Processing Record 148 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# City not found. Skipping...
# Processing Record 149 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?&q=cap malheureux
# Processing Record 150 | Polyarny
# http://api.openweathermap.org/data/2.5/weather?&q=polyarnyy
# Processing Record 151 | Nizhniy Ingash
# http://api.openweathermap.org/data/2.5/weather?&q=nizhniy ingash
# Processing Record 152 | Tallahassee
# http://api.openweathermap.org/data/2.5/weather?&q=tallahassee
# Processing Record 153 | Harper
# http://api.openweathermap.org/data/2.5/weather?&q=harper
# Processing Record 154 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?&q=kangaatsiaq
# City not found. Skipping...
# Processing Record 155 | Kaihua
# http://api.openweathermap.org/data/2.5/weather?&q=kaihua
# Processing Record 156 | Lázaro Cárdenas
# http://api.openweathermap.org/data/2.5/weather?&q=lazaro cardenas
# Processing Record 157 | Khāsh
# http://api.openweathermap.org/data/2.5/weather?&q=khash
# Processing Record 158 | Pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 159 | Chui
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 160 | Solina
# http://api.openweathermap.org/data/2.5/weather?&q=solina
# Processing Record 161 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 162 | Vilhena
# http://api.openweathermap.org/data/2.5/weather?&q=vilhena
# Processing Record 163 | Ailigandí
# http://api.openweathermap.org/data/2.5/weather?&q=ailigandi
# Processing Record 164 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 165 | Yabēlo
# http://api.openweathermap.org/data/2.5/weather?&q=yabelo
# Processing Record 166 | Batangafo
# http://api.openweathermap.org/data/2.5/weather?&q=batangafo
# Processing Record 167 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 168 | Hastings
# http://api.openweathermap.org/data/2.5/weather?&q=hastings
# Processing Record 169 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?&q=bengkulu
# Processing Record 170 | Northam
# http://api.openweathermap.org/data/2.5/weather?&q=northam
# Processing Record 171 | Faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 172 | Faya
# http://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 173 | Hirara
# http://api.openweathermap.org/data/2.5/weather?&q=hirara
# Processing Record 174 | Machilipatnam
# http://api.openweathermap.org/data/2.5/weather?&q=machilipatnam
# Processing Record 175 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# Processing Record 176 | Coyah
# http://api.openweathermap.org/data/2.5/weather?&q=coyah
# Processing Record 177 | Wewak
# http://api.openweathermap.org/data/2.5/weather?&q=wewak
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 178 | Benguela
# http://api.openweathermap.org/data/2.5/weather?&q=benguela
# Processing Record 179 | Laas
# http://api.openweathermap.org/data/2.5/weather?&q=lasa
# Processing Record 180 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?&q=olafsvik
# Processing Record 181 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?&q=plettenberg bay
# Processing Record 182 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 183 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 184 | Hornepayne
# http://api.openweathermap.org/data/2.5/weather?&q=hornepayne
# Processing Record 185 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 186 | Tambilil
# http://api.openweathermap.org/data/2.5/weather?&q=tambilil
# Processing Record 187 | Bereda
# http://api.openweathermap.org/data/2.5/weather?&q=bereda
# Processing Record 188 | Paso de los Toros
# http://api.openweathermap.org/data/2.5/weather?&q=paso de los toros
# Processing Record 189 | Rena
# http://api.openweathermap.org/data/2.5/weather?&q=rena
# Processing Record 190 | Mahālingpur
# http://api.openweathermap.org/data/2.5/weather?&q=mahalingpur
# Processing Record 191 | Avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 192 | Maamba
# http://api.openweathermap.org/data/2.5/weather?&q=maamba
# Processing Record 193 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 194 | Stutterheim
# http://api.openweathermap.org/data/2.5/weather?&q=stutterheim
# Processing Record 195 | Margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 196 | Gladstone
# http://api.openweathermap.org/data/2.5/weather?&q=gladstone
# Processing Record 197 | Dzidzantun
# http://api.openweathermap.org/data/2.5/weather?&q=dzidzantun
# Processing Record 198 | Sydney
# http://api.openweathermap.org/data/2.5/weather?&q=sidney
# Processing Record 199 | Stranda
# http://api.openweathermap.org/data/2.5/weather?&q=stranda
# Processing Record 200 | Lagos
# http://api.openweathermap.org/data/2.5/weather?&q=lagos
# Processing Record 201 | Esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 202 | Abashiri
# http://api.openweathermap.org/data/2.5/weather?&q=abashiri
# Processing Record 203 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# City not found. Skipping...
# Processing Record 204 | Santa Cruz de la Sierra
# http://api.openweathermap.org/data/2.5/weather?&q=santa cruz
# Processing Record 205 | Udgīr
# http://api.openweathermap.org/data/2.5/weather?&q=udgir
# Processing Record 206 | Kyra
# http://api.openweathermap.org/data/2.5/weather?&q=kyra
# Processing Record 207 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 208 | Constitución
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 209 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 210 | Madimba
# http://api.openweathermap.org/data/2.5/weather?&q=madimba
# Processing Record 211 | Río Gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 212 | Sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 213 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 214 | Thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 215 | Neiafu
# http://api.openweathermap.org/data/2.5/weather?&q=neiafu
# Processing Record 216 | Yangi Marg`ilon
# http://api.openweathermap.org/data/2.5/weather?&q=komsomolskiy
# Processing Record 217 | Havre-St-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# Processing Record 218 | Mozarlândia
# http://api.openweathermap.org/data/2.5/weather?&q=mozarlandia
# Processing Record 219 | Kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 220 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 221 | Souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 222 | Neftçala
# http://api.openweathermap.org/data/2.5/weather?&q=neftcala
# Processing Record 223 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?&q=mogadishu
# Processing Record 224 | Kampot
# http://api.openweathermap.org/data/2.5/weather?&q=kampot
# Processing Record 225 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?&q=kamenka
# Processing Record 226 | Vardø
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# Processing Record 227 | Rawson
# http://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 228 | Lasem
# http://api.openweathermap.org/data/2.5/weather?&q=lasem
# Processing Record 229 | Celestún
# http://api.openweathermap.org/data/2.5/weather?&q=celestun
# Processing Record 230 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 231 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 232 | Noumea
# http://api.openweathermap.org/data/2.5/weather?&q=noumea
# Processing Record 233 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 234 | Isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 235 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?&q=bilibino
# Processing Record 236 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 237 | Camapuã
# http://api.openweathermap.org/data/2.5/weather?&q=camapua
# City not found. Skipping...
# Processing Record 238 | Asău
# http://api.openweathermap.org/data/2.5/weather?&q=asau
# Processing Record 239 | Kichera
# http://api.openweathermap.org/data/2.5/weather?&q=kichera
# Processing Record 240 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?&q=waipawa
# Processing Record 241 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?&q=cabedelo
# Processing Record 242 | Paramonga
# http://api.openweathermap.org/data/2.5/weather?&q=paramonga
# Processing Record 243 | Sweetwater
# http://api.openweathermap.org/data/2.5/weather?&q=sweetwater
# City not found. Skipping...
# Processing Record 244 | Chancay
# http://api.openweathermap.org/data/2.5/weather?&q=chancay
# Processing Record 245 | Eureka
# http://api.openweathermap.org/data/2.5/weather?&q=eureka
# Processing Record 246 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?&q=ca mau
# Processing Record 247 | Khovd
# http://api.openweathermap.org/data/2.5/weather?&q=hovd
# Processing Record 248 | Umreth
# http://api.openweathermap.org/data/2.5/weather?&q=umreth
# Processing Record 249 | Krasnosel'kup
# http://api.openweathermap.org/data/2.5/weather?&q=krasnoselkup
# Processing Record 250 | Khani
# http://api.openweathermap.org/data/2.5/weather?&q=khani
# Processing Record 251 | Grand Bank
# http://api.openweathermap.org/data/2.5/weather?&q=grand bank
# City not found. Skipping...
# Processing Record 252 | Rūdbār
# http://api.openweathermap.org/data/2.5/weather?&q=rudbar
# City not found. Skipping...
# Processing Record 253 | Airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 254 | Saint George
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# City not found. Skipping...
# Processing Record 255 | Nieuw Amsterdam
# http://api.openweathermap.org/data/2.5/weather?&q=nieuw amsterdam
# Processing Record 256 | Kwang Binh
# http://api.openweathermap.org/data/2.5/weather?&q=dong hoi
# Processing Record 257 | Akdepe
# http://api.openweathermap.org/data/2.5/weather?&q=akdepe
# Processing Record 258 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?&q=abu kamal
# Processing Record 259 | Poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 260 | Manzhouli
# http://api.openweathermap.org/data/2.5/weather?&q=manzhouli
# Processing Record 261 | Batken
# http://api.openweathermap.org/data/2.5/weather?&q=batken
# Processing Record 262 | Bakchar
# http://api.openweathermap.org/data/2.5/weather?&q=bakchar
# Processing Record 263 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 264 | Coswig
# http://api.openweathermap.org/data/2.5/weather?&q=coswig
# Processing Record 265 | Bogalusa
# http://api.openweathermap.org/data/2.5/weather?&q=bogalusa
# Processing Record 266 | Burg
# http://api.openweathermap.org/data/2.5/weather?&q=burg
# Processing Record 267 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?&q=santiago del estero
# Processing Record 268 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?&q=hualmay
# Processing Record 269 | Immokalee
# http://api.openweathermap.org/data/2.5/weather?&q=immokalee
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 270 | Fenoarivo Atsinanana
# http://api.openweathermap.org/data/2.5/weather?&q=fenoarivo atsinanana
# Processing Record 271 | Olinda
# http://api.openweathermap.org/data/2.5/weather?&q=olinda
# Processing Record 272 | Chapada dos Guimarães
# http://api.openweathermap.org/data/2.5/weather?&q=chapada dos guimaraes
# Processing Record 273 | Okha
# http://api.openweathermap.org/data/2.5/weather?&q=okha
# Processing Record 274 | Apac
# http://api.openweathermap.org/data/2.5/weather?&q=apac
# Processing Record 275 | Shenzhen
# http://api.openweathermap.org/data/2.5/weather?&q=shenzhen
# Processing Record 276 | Hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# City not found. Skipping...
# Processing Record 277 | Palmas Bellas
# http://api.openweathermap.org/data/2.5/weather?&q=palmas bellas
# Processing Record 278 | Shache
# http://api.openweathermap.org/data/2.5/weather?&q=shache
# City not found. Skipping...
# Processing Record 279 | Itoman
# http://api.openweathermap.org/data/2.5/weather?&q=itoman
# Processing Record 280 | Santoña
# http://api.openweathermap.org/data/2.5/weather?&q=santona
# Processing Record 281 | Namie
# http://api.openweathermap.org/data/2.5/weather?&q=namie
# Processing Record 282 | Bījār
# http://api.openweathermap.org/data/2.5/weather?&q=bijar
# Processing Record 283 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?&q=port moresby
# Processing Record 284 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 285 | Kiama
# http://api.openweathermap.org/data/2.5/weather?&q=kiama
# Processing Record 286 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 287 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 288 | Marawi
# http://api.openweathermap.org/data/2.5/weather?&q=marawi
# Processing Record 289 | Torbat-e Jām
# http://api.openweathermap.org/data/2.5/weather?&q=torbat-e jam
# Processing Record 290 | Biu
# http://api.openweathermap.org/data/2.5/weather?&q=biu
# Processing Record 291 | Agüimes
# http://api.openweathermap.org/data/2.5/weather?&q=aguimes
# Processing Record 292 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?&q=aykhal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 293 | Sémbé
# http://api.openweathermap.org/data/2.5/weather?&q=sembe
# Processing Record 294 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# City not found. Skipping...
# Processing Record 295 | Atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 296 | Phuket
# http://api.openweathermap.org/data/2.5/weather?&q=phuket
# Processing Record 297 | Bonnyville
# http://api.openweathermap.org/data/2.5/weather?&q=bonnyville
# Processing Record 298 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 299 | Mossamedes
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 300 | Buin
# http://api.openweathermap.org/data/2.5/weather?&q=buin
# Processing Record 301 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 302 | San Jose
# http://api.openweathermap.org/data/2.5/weather?&q=san jose
# Processing Record 303 | Along
# http://api.openweathermap.org/data/2.5/weather?&q=along
# City not found. Skipping...
# Processing Record 304 | Matías Romero
# http://api.openweathermap.org/data/2.5/weather?&q=matias romero
# Processing Record 305 | Bom Despacho
# http://api.openweathermap.org/data/2.5/weather?&q=bom despacho
# Processing Record 306 | Fort Smith
# http://api.openweathermap.org/data/2.5/weather?&q=fort smith
# Processing Record 307 | Winslow
# http://api.openweathermap.org/data/2.5/weather?&q=winslow
# Processing Record 308 | Ambulu
# http://api.openweathermap.org/data/2.5/weather?&q=ambulu
# Processing Record 309 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?&q=mount gambier
# Processing Record 310 | Kropotkin
# http://api.openweathermap.org/data/2.5/weather?&q=kropotkin
# Processing Record 311 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?&q=solnechnyy
# Processing Record 312 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 313 | Puerto Carreño
# http://api.openweathermap.org/data/2.5/weather?&q=puerto carreno
# Processing Record 314 | Kampong Cham
# http://api.openweathermap.org/data/2.5/weather?&q=kampong cham
# Processing Record 315 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?&q=bubaque
# Processing Record 316 | Tahe
# http://api.openweathermap.org/data/2.5/weather?&q=tahe
# Processing Record 317 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# Processing Record 318 | Churapcha
# http://api.openweathermap.org/data/2.5/weather?&q=churapcha
# Processing Record 319 | Izhevsk
# http://api.openweathermap.org/data/2.5/weather?&q=izhevsk
# Processing Record 320 | Melchor de Mencos
# http://api.openweathermap.org/data/2.5/weather?&q=melchor de mencos
# Processing Record 321 | Uglich
# http://api.openweathermap.org/data/2.5/weather?&q=uglich
# City not found. Skipping...
# Processing Record 322 | Pomabamba
# http://api.openweathermap.org/data/2.5/weather?&q=pomabamba
# Processing Record 323 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?&q=muzhi
# Processing Record 324 | Arlit
# http://api.openweathermap.org/data/2.5/weather?&q=arlit
# Processing Record 325 | Kerema
# http://api.openweathermap.org/data/2.5/weather?&q=kerema
# Processing Record 326 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?&q=waingapu
# Processing Record 327 | Vallenar
# http://api.openweathermap.org/data/2.5/weather?&q=vallenar
# City not found. Skipping...
# Processing Record 328 | Borogontsy
# http://api.openweathermap.org/data/2.5/weather?&q=borogontsy
# Processing Record 329 | Urengoy
# http://api.openweathermap.org/data/2.5/weather?&q=urengoy
# Processing Record 330 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?&q=port macquarie
# Processing Record 331 | Japura
# http://api.openweathermap.org/data/2.5/weather?&q=japura
# Processing Record 332 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 333 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# Processing Record 334 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?&q=meulaboh
# Processing Record 335 | Chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 336 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?&q=santa rosa
# Processing Record 337 | Xique-Xique
# http://api.openweathermap.org/data/2.5/weather?&q=xique-xique
# Processing Record 338 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 339 | Togur
# http://api.openweathermap.org/data/2.5/weather?&q=togur
# Processing Record 340 | Taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# City not found. Skipping...
# Processing Record 341 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 342 | Ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 343 | Uberlândia
# http://api.openweathermap.org/data/2.5/weather?&q=uberlandia
# Processing Record 344 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnevilyuysk
# Processing Record 345 | Manggar
# http://api.openweathermap.org/data/2.5/weather?&q=manggar
# Processing Record 346 | Neosho
# http://api.openweathermap.org/data/2.5/weather?&q=neosho
# City not found. Skipping...
# Processing Record 347 | Alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# City not found. Skipping...
# Processing Record 348 | Kinwat
# http://api.openweathermap.org/data/2.5/weather?&q=kinwat
# Processing Record 349 | Katangli
# http://api.openweathermap.org/data/2.5/weather?&q=katangli
# Processing Record 350 | San Lorenzo
# http://api.openweathermap.org/data/2.5/weather?&q=san lorenzo
# Processing Record 351 | Silopi
# http://api.openweathermap.org/data/2.5/weather?&q=silopi
# Processing Record 352 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 353 | Hay River
# http://api.openweathermap.org/data/2.5/weather?&q=hay river
# Processing Record 354 | Sulangan
# http://api.openweathermap.org/data/2.5/weather?&q=sulangan
# Processing Record 355 | Partenit
# http://api.openweathermap.org/data/2.5/weather?&q=partenit
# Processing Record 356 | Sakakah
# http://api.openweathermap.org/data/2.5/weather?&q=sakakah
# Processing Record 357 | Kostomuksha
# http://api.openweathermap.org/data/2.5/weather?&q=kostomuksha
# Processing Record 358 | Vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 359 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# Processing Record 360 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?&q=kisangani
# Processing Record 361 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?&q=nantucket
# City not found. Skipping...
# Processing Record 362 | Labytnangi
# http://api.openweathermap.org/data/2.5/weather?&q=labytnangi
# Processing Record 363 | Garoowe
# http://api.openweathermap.org/data/2.5/weather?&q=garowe
# Processing Record 364 | Viedma
# http://api.openweathermap.org/data/2.5/weather?&q=viedma
# Processing Record 365 | Paita
# http://api.openweathermap.org/data/2.5/weather?&q=paita
# Processing Record 366 | Kismayo
# http://api.openweathermap.org/data/2.5/weather?&q=kismayo
# Processing Record 367 | Matagami
# http://api.openweathermap.org/data/2.5/weather?&q=matagami
# Processing Record 368 | ‘Āhuimanu
# http://api.openweathermap.org/data/2.5/weather?&q=ahuimanu
# Processing Record 369 | Kargasok
# http://api.openweathermap.org/data/2.5/weather?&q=kargasok
# Processing Record 370 | Gazli
# http://api.openweathermap.org/data/2.5/weather?&q=gazli
# Processing Record 371 | Paphos
# http://api.openweathermap.org/data/2.5/weather?&q=pafos
# Processing Record 372 | Goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 373 | Bose
# http://api.openweathermap.org/data/2.5/weather?&q=bose
# Processing Record 374 | Bull Savanna
# http://api.openweathermap.org/data/2.5/weather?&q=bull savanna
# Processing Record 375 | Rantepao
# http://api.openweathermap.org/data/2.5/weather?&q=rantepao
# Processing Record 376 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?&q=hambantota
# Processing Record 377 | Marinette
# http://api.openweathermap.org/data/2.5/weather?&q=marinette
# Processing Record 378 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?&q=khandyga
# Processing Record 379 | Taksimo
# http://api.openweathermap.org/data/2.5/weather?&q=taksimo
# Processing Record 380 | Maridi
# http://api.openweathermap.org/data/2.5/weather?&q=maridi
# Processing Record 381 | Aleksandrovsk
# http://api.openweathermap.org/data/2.5/weather?&q=aleksandrovsk
# Processing Record 382 | Skeldon
# http://api.openweathermap.org/data/2.5/weather?&q=skeldon
# Processing Record 383 | Kjøllefjord
# http://api.openweathermap.org/data/2.5/weather?&q=kjollefjord
# Processing Record 384 | Honiara
# http://api.openweathermap.org/data/2.5/weather?&q=honiara
# Processing Record 385 | Winnemucca
# http://api.openweathermap.org/data/2.5/weather?&q=winnemucca
# Processing Record 386 | Baie-Saint-Paul
# http://api.openweathermap.org/data/2.5/weather?&q=baie-saint-paul
# Processing Record 387 | Bemidji
# http://api.openweathermap.org/data/2.5/weather?&q=bemidji
# Processing Record 388 | Maxixe
# http://api.openweathermap.org/data/2.5/weather?&q=maxixe
# Processing Record 389 | Kāzerūn
# http://api.openweathermap.org/data/2.5/weather?&q=kazerun
# Processing Record 390 | Amga
# http://api.openweathermap.org/data/2.5/weather?&q=amga
# Processing Record 391 | Esim
# http://api.openweathermap.org/data/2.5/weather?&q=axim
# Processing Record 392 | Esmeraldas
# http://api.openweathermap.org/data/2.5/weather?&q=esmeraldas
# City not found. Skipping...
# Processing Record 393 | Yangjiang
# http://api.openweathermap.org/data/2.5/weather?&q=yangjiang
# City not found. Skipping...
# Processing Record 394 | Ayan
# http://api.openweathermap.org/data/2.5/weather?&q=ayan
# Processing Record 395 | Sfântu Gheorghe
# http://api.openweathermap.org/data/2.5/weather?&q=sfantu gheorghe
# Processing Record 396 | Grants
# http://api.openweathermap.org/data/2.5/weather?&q=grants
# Processing Record 397 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?&q=prince rupert
# Processing Record 398 | Cabo Rojo
# http://api.openweathermap.org/data/2.5/weather?&q=cabo rojo
# Processing Record 399 | Mananjary
# http://api.openweathermap.org/data/2.5/weather?&q=mananjary
# Processing Record 400 | Pacifica
# http://api.openweathermap.org/data/2.5/weather?&q=pacifica
# Processing Record 401 | Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?&q=tres arroyos
# Processing Record 402 | Santa Cruz del Sur
# http://api.openweathermap.org/data/2.5/weather?&q=santa cruz del sur
# City not found. Skipping...
# Processing Record 403 | Hargeisa
# http://api.openweathermap.org/data/2.5/weather?&q=hargeysa
# City not found. Skipping...
# Processing Record 404 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 405 | Svetlaya
# http://api.openweathermap.org/data/2.5/weather?&q=svetlaya
# Processing Record 406 | Kyshtovka
# http://api.openweathermap.org/data/2.5/weather?&q=kyshtovka
# Processing Record 407 | Voh
# http://api.openweathermap.org/data/2.5/weather?&q=voh
# Processing Record 408 | Urucará
# http://api.openweathermap.org/data/2.5/weather?&q=urucara
# Processing Record 409 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# Processing Record 410 | Salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 411 | Leh
# http://api.openweathermap.org/data/2.5/weather?&q=leh
# Processing Record 412 | Rognan
# http://api.openweathermap.org/data/2.5/weather?&q=rognan
# Processing Record 413 | Morondava
# http://api.openweathermap.org/data/2.5/weather?&q=morondava
# Processing Record 414 | Ponto Novo
# http://api.openweathermap.org/data/2.5/weather?&q=ponto novo
# Processing Record 415 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?&q=luwuk
# Processing Record 416 | Lishu
# http://api.openweathermap.org/data/2.5/weather?&q=lishu
# Processing Record 417 | Santa Maria da Vitória
# http://api.openweathermap.org/data/2.5/weather?&q=santa maria da vitoria
# Processing Record 418 | Aksu
# http://api.openweathermap.org/data/2.5/weather?&q=aksu
# Processing Record 419 | Zarubino
# http://api.openweathermap.org/data/2.5/weather?&q=zarubino
# Processing Record 420 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?&q=gigmoto
# Processing Record 421 | Jiayuguan City
# http://api.openweathermap.org/data/2.5/weather?&q=jiayuguan
# Processing Record 422 | Gashua
# http://api.openweathermap.org/data/2.5/weather?&q=gashua
# Processing Record 423 | San Francisco de Ojuera
# http://api.openweathermap.org/data/2.5/weather?&q=san francisco de ojuera
# Processing Record 424 | Thunder Bay
# http://api.openweathermap.org/data/2.5/weather?&q=thunder bay
# Processing Record 425 | Gijang
# http://api.openweathermap.org/data/2.5/weather?&q=kijang
# Processing Record 426 | Chala
# http://api.openweathermap.org/data/2.5/weather?&q=chala
# Processing Record 427 | Humberto de Campos
# http://api.openweathermap.org/data/2.5/weather?&q=humberto de campos
# Processing Record 428 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# Processing Record 429 | Shakiso
# http://api.openweathermap.org/data/2.5/weather?&q=shakiso
# Processing Record 430 | Três Lagoas
# http://api.openweathermap.org/data/2.5/weather?&q=tres lagoas
# Processing Record 431 | Ust'-Kut
# http://api.openweathermap.org/data/2.5/weather?&q=ust-kut
# Processing Record 432 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?&q=erenhot
# Processing Record 433 | Khor
# http://api.openweathermap.org/data/2.5/weather?&q=khor
# Processing Record 434 | Kachīry
# http://api.openweathermap.org/data/2.5/weather?&q=kachiry
# Processing Record 435 | Aiken
# http://api.openweathermap.org/data/2.5/weather?&q=aiken
# Processing Record 436 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?&q=saint-joseph
# Processing Record 437 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 438 | Jalu
# http://api.openweathermap.org/data/2.5/weather?&q=jalu
# Processing Record 439 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?&q=labuhan
# Processing Record 440 | De Aar
# http://api.openweathermap.org/data/2.5/weather?&q=de aar
# Processing Record 441 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 442 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# City not found. Skipping...
# Processing Record 443 | La Grande
# http://api.openweathermap.org/data/2.5/weather?&q=la grande
# Processing Record 444 | Vila do Maio
# http://api.openweathermap.org/data/2.5/weather?&q=vila do maio
# Processing Record 445 | Homer
# http://api.openweathermap.org/data/2.5/weather?&q=homer
# Processing Record 446 | Sur
# http://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 447 | Mpika
# http://api.openweathermap.org/data/2.5/weather?&q=mpika
# Processing Record 448 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?&q=nemuro
# City not found. Skipping...
# Processing Record 449 | Mayo
# http://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 450 | Kula
# http://api.openweathermap.org/data/2.5/weather?&q=kula
# Processing Record 451 | Bantogon
# http://api.openweathermap.org/data/2.5/weather?&q=bantogon
# City not found. Skipping...
# Processing Record 452 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 453 | Valdivia
# http://api.openweathermap.org/data/2.5/weather?&q=valdivia
# Processing Record 454 | Kurikka
# http://api.openweathermap.org/data/2.5/weather?&q=kurikka
# Processing Record 455 | Aden
# http://api.openweathermap.org/data/2.5/weather?&q=aden
# Processing Record 456 | Nísia Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=nisia floresta
# Processing Record 457 | San Jerónimo
# http://api.openweathermap.org/data/2.5/weather?&q=san jeronimo
# Processing Record 458 | Serebryansk
# http://api.openweathermap.org/data/2.5/weather?&q=serebryansk
# Processing Record 459 | Torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 460 | Kingaroy
# http://api.openweathermap.org/data/2.5/weather?&q=kingaroy
# Processing Record 461 | Kaura Namoda
# http://api.openweathermap.org/data/2.5/weather?&q=kaura namoda
# Processing Record 462 | Longido
# http://api.openweathermap.org/data/2.5/weather?&q=longido
# Processing Record 463 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# City not found. Skipping...
# Processing Record 464 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?&q=gorontalo
# Processing Record 465 | Constantine
# http://api.openweathermap.org/data/2.5/weather?&q=constantine
# Processing Record 466 | Bam
# http://api.openweathermap.org/data/2.5/weather?&q=bam
# Processing Record 467 | Nuevitas
# http://api.openweathermap.org/data/2.5/weather?&q=nuevitas
# Processing Record 468 | Baijiantan
# http://api.openweathermap.org/data/2.5/weather?&q=baijiantan
# Processing Record 469 | Coyhaique
# http://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 470 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# Processing Record 471 | Isla Vista
# http://api.openweathermap.org/data/2.5/weather?&q=isla vista
# Processing Record 472 | West Wendover
# http://api.openweathermap.org/data/2.5/weather?&q=west wendover
# Processing Record 473 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 474 | Hede
# http://api.openweathermap.org/data/2.5/weather?&q=hede
# Processing Record 475 | São Filipe
# http://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 476 | Gamba
# http://api.openweathermap.org/data/2.5/weather?&q=gamba
# Processing Record 477 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?&q=haines junction
# Processing Record 478 | Gura Teghii
# http://api.openweathermap.org/data/2.5/weather?&q=gura teghii
# Processing Record 479 | Zabaykal'sk
# http://api.openweathermap.org/data/2.5/weather?&q=zabaykalsk
# Processing Record 480 | Newcastle
# http://api.openweathermap.org/data/2.5/weather?&q=newcastle
# Processing Record 481 | Nosy Varika
# http://api.openweathermap.org/data/2.5/weather?&q=nosy varika
# Processing Record 482 | El Bordo
# http://api.openweathermap.org/data/2.5/weather?&q=el bordo
# Processing Record 483 | Dingle
# http://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 484 | Koubia
# http://api.openweathermap.org/data/2.5/weather?&q=koubia
# Processing Record 485 | Raebareli
# http://api.openweathermap.org/data/2.5/weather?&q=rae bareli
# Processing Record 486 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 487 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 488 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?&q=marzuq
# Processing Record 489 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 490 | Caucayá
# http://api.openweathermap.org/data/2.5/weather?&q=puerto leguizamo
# Processing Record 491 | Palmer
# http://api.openweathermap.org/data/2.5/weather?&q=palmer
# Processing Record 492 | Thoen
# http://api.openweathermap.org/data/2.5/weather?&q=thoen
# Processing Record 493 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 494 | Zhangzhou
# http://api.openweathermap.org/data/2.5/weather?&q=zhangzhou
# Processing Record 495 | Helong
# http://api.openweathermap.org/data/2.5/weather?&q=helong
# Processing Record 496 | Loreto
# http://api.openweathermap.org/data/2.5/weather?&q=loreto
# Processing Record 497 | Lerwick
# http://api.openweathermap.org/data/2.5/weather?&q=lerwick
# Processing Record 498 | Formosa do Rio Preto
# http://api.openweathermap.org/data/2.5/weather?&q=formosa do rio preto
# Processing Record 499 | Taldan
# http://api.openweathermap.org/data/2.5/weather?&q=taldan
# Processing Record 500 | Nsanje
# http://api.openweathermap.org/data/2.5/weather?&q=nsanje
# Processing Record 501 | Swan Hill
# http://api.openweathermap.org/data/2.5/weather?&q=swan hill
# Processing Record 502 | Waverley
# http://api.openweathermap.org/data/2.5/weather?&q=waverley
# Processing Record 503 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 504 | Platýkampos
# http://api.openweathermap.org/data/2.5/weather?&q=platikambos
# Processing Record 505 | Guozhen
# http://api.openweathermap.org/data/2.5/weather?&q=guozhen
# Processing Record 506 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?&q=oranjemund
# Processing Record 507 | Yadgir
# http://api.openweathermap.org/data/2.5/weather?&q=yadgir
# Processing Record 508 | Muroto-misakicho
# http://api.openweathermap.org/data/2.5/weather?&q=muroto
# Processing Record 509 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?&q=port-cartier
# Processing Record 510 | Keti Bandar
# http://api.openweathermap.org/data/2.5/weather?&q=keti bandar
# Processing Record 511 | Abū Zabad
# http://api.openweathermap.org/data/2.5/weather?&q=abu zabad
# Processing Record 512 | Kumul
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 513 | Ballina
# http://api.openweathermap.org/data/2.5/weather?&q=ballina
# Processing Record 514 | Barranca
# http://api.openweathermap.org/data/2.5/weather?&q=barranca
# City not found. Skipping...
# Processing Record 515 | Taunggyi
# http://api.openweathermap.org/data/2.5/weather?&q=taunggyi
# Processing Record 516 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# Processing Record 517 | Avigliano
# http://api.openweathermap.org/data/2.5/weather?&q=avigliano
# Processing Record 518 | Moreira Sales
# http://api.openweathermap.org/data/2.5/weather?&q=moreira sales
# Processing Record 519 | Winsum
# http://api.openweathermap.org/data/2.5/weather?&q=winsum
# Processing Record 520 | Ürümqi
# http://api.openweathermap.org/data/2.5/weather?&q=urumqi
# Processing Record 521 | Griffith
# http://api.openweathermap.org/data/2.5/weather?&q=griffith
# Processing Record 522 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?&q=aksarka
# Processing Record 523 | East Wenatchee Bench
# http://api.openweathermap.org/data/2.5/weather?&q=east wenatchee bench
# City not found. Skipping...
# Processing Record 524 | Kollo
# http://api.openweathermap.org/data/2.5/weather?&q=kollo
# Processing Record 525 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?&q=turukhansk
# Processing Record 526 | Ryōtsu-minato
# http://api.openweathermap.org/data/2.5/weather?&q=ryotsu
# Processing Record 527 | Dauriya
# http://api.openweathermap.org/data/2.5/weather?&q=dauriya
# City not found. Skipping...
# Processing Record 528 | Codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 529 | Tolaga Bay
# http://api.openweathermap.org/data/2.5/weather?&q=tolaga bay
# Processing Record 530 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# Processing Record 531 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?&q=vestmanna
# Processing Record 532 | Huallanca
# http://api.openweathermap.org/data/2.5/weather?&q=huallanca
# Processing Record 533 | Gimli
# http://api.openweathermap.org/data/2.5/weather?&q=gimli
# Processing Record 534 | Bluefields
# http://api.openweathermap.org/data/2.5/weather?&q=bluefields
# Processing Record 535 | Kalevala
# http://api.openweathermap.org/data/2.5/weather?&q=kalevala
# Processing Record 536 | Chipinge
# http://api.openweathermap.org/data/2.5/weather?&q=chipinge
# Processing Record 537 | Ongandjera
# http://api.openweathermap.org/data/2.5/weather?&q=ongandjera
# Processing Record 538 | Alta Gracia
# http://api.openweathermap.org/data/2.5/weather?&q=alta gracia
# Processing Record 539 | Luga
# http://api.openweathermap.org/data/2.5/weather?&q=laukaa
# Processing Record 540 | Palmares
# http://api.openweathermap.org/data/2.5/weather?&q=palmares
# City not found. Skipping...
# Processing Record 541 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 542 | Tuntum
# http://api.openweathermap.org/data/2.5/weather?&q=tuntum
# Processing Record 543 | Nurota
# http://api.openweathermap.org/data/2.5/weather?&q=nurota
# Processing Record 544 | Jhālrapātan
# http://api.openweathermap.org/data/2.5/weather?&q=jhalrapatan
# Processing Record 545 | Linjiang
# http://api.openweathermap.org/data/2.5/weather?&q=linjiang
# Processing Record 546 | Purpe
# http://api.openweathermap.org/data/2.5/weather?&q=purpe
# Processing Record 547 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 548 | Acarí
# http://api.openweathermap.org/data/2.5/weather?&q=acari
# Processing Record 549 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?&q=santa maria
# City not found. Skipping...
# Processing Record 550 | Arica
# http://api.openweathermap.org/data/2.5/weather?&q=arica
# Processing Record 551 | Cootamundra
# http://api.openweathermap.org/data/2.5/weather?&q=cootamundra
# Processing Record 552 | Ocean City
# http://api.openweathermap.org/data/2.5/weather?&q=ocean city
# Processing Record 553 | Kattivākkam
# http://api.openweathermap.org/data/2.5/weather?&q=kattivakkam
# Processing Record 554 | Erzin
# http://api.openweathermap.org/data/2.5/weather?&q=erzin
# Processing Record 555 | Camacha
# http://api.openweathermap.org/data/2.5/weather?&q=camacha
# City not found. Skipping...
# Processing Record 556 | Coxim
# http://api.openweathermap.org/data/2.5/weather?&q=coxim
# Processing Record 557 | Hutang
# http://api.openweathermap.org/data/2.5/weather?&q=hutang
# Processing Record 558 | Nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# City not found. Skipping...
# Processing Record 559 | Bodden Town
# http://api.openweathermap.org/data/2.5/weather?&q=bodden town
# Processing Record 560 | Tabou
# http://api.openweathermap.org/data/2.5/weather?&q=tabou
# Processing Record 561 | Macenta
# http://api.openweathermap.org/data/2.5/weather?&q=macenta
# Processing Record 562 | Rochegda
# http://api.openweathermap.org/data/2.5/weather?&q=rochegda
# Processing Record 563 | Mirik
# http://api.openweathermap.org/data/2.5/weather?&q=mirik

# %%
# create a dictionary to construct dataframe
weather_py = {"City":city_name,
             "Lat":lat,
             "Lng":lng,
             "Max Temp":max_temp,
             "Humidity":humidity,
             "Cloudiness":cloudiness,
             "Wind Speed":wind_speed,
             "Country":country,
             "date":date
             }

weather_df = pd.DataFrame(weather_py)
weather_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kaitangata -46.2817  169.8464     66.00        63           0
# 1              Pisco -13.7000  -76.2167     71.01        94           0
# 2    Bambous Virieux -20.3428   57.7575     80.60        74          40
# 3           Balyqshy  47.0667   51.8667     10.40        79           0
# 4      Alice Springs -23.7000  133.8833     73.40        88          40
# ..               ...      ...       ...       ...       ...         ...
# 558      Bodden Town  19.2833  -81.2500     79.00        61           0
# 559            Tabou   4.4230   -7.3528     77.41        90          67
# 560          Macenta   8.5435   -9.4710     69.04        94          91
# 561         Rochegda  62.8000   43.2500     10.17        92         100
# 562            Mirik  26.8945   88.1848     71.38        28           0
#
#      Wind Speed Country        date
# 0          8.99      NZ  1615605260
# 1          4.61      PE  1615605261
# 2         11.50      MU  1615605263
# 3          8.95      KZ  1615605264
# 4          9.22      AU  1615605265
# ..          ...     ...         ...
# 558       10.36      KY  1615606371
# 559        6.80      CI  1615606373
# 560        1.14      GN  1615606374
# 561        9.51      RU  1615606376
# 562        5.17      IN  1615606377
#
# [563 rows x 9 columns]

# %%
# Export the city data into a CSV
weather_df.to_csv('../output_data/city_data.csv')

# %%
weather_df[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'date']].describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    19.336849   19.583145   53.831119   71.532860   50.127886    8.807620
# std     33.923780   91.945486   26.786542   20.390413   40.166575    6.564332
# min    -54.800000 -179.166700  -20.200000    6.000000    0.000000    0.110000
# 25%    -10.331950  -63.574150   36.000000   60.000000    2.000000    4.000000
# 50%     22.285500   25.570100   62.600000   76.000000   49.000000    7.000000
# 75%     47.570100  102.543350   74.930000   88.000000   91.000000   12.190000
# max     78.218600  179.316700  101.550000  100.000000  100.000000   44.870000
#
#                date
# count  5.630000e+02
# mean   1.615606e+09
# std    3.305034e+02
# min    1.615605e+09
# 25%    1.615605e+09
# 50%    1.615606e+09
# 75%    1.615606e+09
# max    1.615606e+09

# %%
#weather_df = weather_df.loc[weather_df['Humidity'] >100 ]
#weather_df.count()

# %% [markdown]
# # Plotting the Data

# %% [markdown]
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.\
# Save the plotted figures as .pngs.

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolors = "black")
plt.title("City Latitude vs. Max Temperature (03/11/2021)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolors = "black")
plt.title("City Latitude vs. Humidity (03/11/2021)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], edgecolors = "black")
plt.title("City Latitude vs. Cloudiness (03/11/2021)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], edgecolors = "black")
plt.title("City Latitude vs. Wind Speed (03/11/2021)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %% [markdown]
# # Linear Regression

# %%
north_hem = weather_df.loc[weather_df['Lat']>=0]
south_hem = weather_df.loc[weather_df['Lat']<0]

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Max Temp'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
print(f"The r-value is: {r}")
plt.scatter(north_hem['Lat'],north_hem['Max Temp'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.annotate(val, (5,245), fontsize=14, color='red')
plt.show()
# Out:
# The r-value is: -0.8980975271500651

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(south_hem['Lat'],south_hem['Max Temp'])
fit = s * south_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
print(f"The r-value is: {r}")
plt.scatter(south_hem['Lat'],south_hem['Max Temp'])
plt.plot(south_hem['Lat'], fit, "--", color='red')
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.annotate(val, (-30,280), fontsize=14, color='red')
plt.show()
# Out:
# The r-value is: 0.4294055558171901

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Humidity'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
print(f"The r-value is: {r}")
plt.scatter(north_hem['Lat'],north_hem['Humidity'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Humidity ')
plt.xlabel('Latitude')
plt.annotate(val, (50,18), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is: 0.25719209609694993

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(south_hem['Lat'],south_hem['Humidity'])
fit = s * south_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
print(f"The r-value is: {r}")
plt.scatter(south_hem['Lat'],south_hem['Humidity'])
plt.plot(south_hem['Lat'], fit, "--", color='red')
plt.ylabel('Humidity ')
plt.xlabel('Latitude')
plt.annotate(val, (-20,30), fontsize=12, color='red')
plt.show()
# Out:
# The r-value is: 0.21965674780604985

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Cloudiness'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
print(f"The r-value is: {r}")
plt.scatter(north_hem['Lat'],north_hem['Cloudiness'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Cloudiness ')
plt.xlabel('Latitude')
plt.annotate(val, (45,10), fontsize=14, color='red')
plt.show()
# Out:
# The r-value is: 0.24214893951145855

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(south_hem['Lat'],south_hem['Cloudiness'])
fit = s * south_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
print(f"The r-value is: {r}")
plt.scatter(south_hem['Lat'],south_hem['Cloudiness'])
plt.plot(south_hem['Lat'], fit, "--", color='red')
plt.ylabel('Cloudiness ')
plt.xlabel('Latitude')
plt.annotate(val, (-45,18), fontsize=14, color='red')
plt.show()
# Out:
# The r-value is: 0.31466631430951564

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(north_hem['Lat'],north_hem['Wind Speed'])
fit = s * north_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(north_hem['Lat'],north_hem['Wind Speed'])
plt.plot(north_hem['Lat'], fit, "--", color='red')
plt.ylabel('Wind Speed ')
plt.xlabel('Latitude')
plt.annotate(val, (0,30), fontsize=14, color='red')
plt.show()

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s,i,r,p,s_err = st.linregress(south_hem['Lat'],south_hem['Wind Speed'])
fit = s * south_hem['Lat'] + i
val = f'y = {round(s,2)}x + {round(i,2)}'
plt.scatter(south_hem['Lat'],south_hem['Wind Speed'])
plt.plot(south_hem['Lat'], fit, "--", color='red')
plt.ylabel('Wind Speed ')
plt.xlabel('Latitude')
plt.annotate(val, (-30,30), fontsize=14, color='red')
plt.show()
